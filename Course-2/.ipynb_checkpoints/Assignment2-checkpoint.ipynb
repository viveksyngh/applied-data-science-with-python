# %% [markdown]
# # Assignment 2
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# An NOAA dataset has been stored in the file `data/C2A2_data/BinnedCsvs_d400/fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv`. The data for this assignment comes from a subset of The National Centers for Environmental Information (NCEI) [Daily Global Historical Climatology Network](https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/readme.txt) (GHCN-Daily). The GHCN-Daily is comprised of daily climate records from thousands of land surface stations across the globe.
#
# Each row in the assignment datafile corresponds to a single observation.
#
# The following variables are provided to you:
#
# * **id** : station identification code
# * **date** : date in YYYY-MM-DD format (e.g. 2012-01-24 = January 24, 2012)
# * **element** : indicator of element type
#     * TMAX : Maximum temperature (tenths of degrees C)
#     * TMIN : Minimum temperature (tenths of degrees C)
# * **value** : data value for element (tenths of degrees C)
#
# For this assignment, you must:
#
# 1. Read the documentation and familiarize yourself with the dataset, then write some python code which returns a line graph of the record high and record low temperatures by day of the year over the period 2005-2014. The area between the record high and record low temperatures for each day should be shaded.
# 2. Overlay a scatter of the 2015 data for any points (highs and lows) for which the ten year record (2005-2014) record high or record low was broken in 2015.
# 3. Watch out for leap days (i.e. February 29th), it is reasonable to remove these points from the dataset for the purpose of this visualization.
# 4. Make the visual nice! Leverage principles from the first module in this course when developing your solution. Consider issues such as legends, labels, and chart junk.
#
# The data you have been given is near **Ann Arbor, Michigan, United States**, and the stations the data comes from are shown on the map below.

# %%
import matplotlib.pyplot as plt
import mplleaflet
import pandas as pd

def leaflet_plot_stations(binsize, hashid):

    df = pd.read_csv('data/C2A2_data/BinSize_d{}.csv'.format(binsize))

    station_locations_by_hash = df[df['hash'] == hashid]

    lons = station_locations_by_hash['LONGITUDE'].tolist()
    lats = station_locations_by_hash['LATITUDE'].tolist()

    plt.figure(figsize=(8,8))

    plt.scatter(lons, lats, c='r', alpha=0.7, s=200)

    return mplleaflet.display()

leaflet_plot_stations(400,'fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5a794b262961> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 import mplleaflet
#       3 import pandas as pd
#       4
#       5 def leaflet_plot_stations(binsize, hashid):
#
# ModuleNotFoundError: No module named 'mplleaflet'

# %% [markdown]
# ## Load the dataset

# %%
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
climate_data = pd.read_csv('data/C2A2_data/BinnedCsvs_d400/fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv')
print(len(climate_data))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-438e03d6886d> in <module>()
# ----> 1 climate_data = pd.read_csv('data/C2A2_data/BinnedCsvs_d400/fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv')
#       2 print(len(climate_data))
#
# ...

# %%
climate_data['Datetime'] = climate_data['Date'].apply(pd.to_datetime)

# %%
climate_data['Date'] = climate_data['Datetime'].dt.date
climate_data['Year'] = climate_data['Datetime'].dt.year
climate_data['Day'] = climate_data['Datetime'].dt.day
climate_data['Month'] = climate_data['Datetime'].dt.month
climate_data.head()
len(climate_data)
# Out:
# 165085

# %%
climate_data = climate_data[~((climate_data['Day'] == 29) & (climate_data['Month'] == 2))]
len(climate_data)
# Out:
# 165002

# %%
climate_data_new = climate_data[climate_data['Year'] >= 2015]
climate_data = climate_data[climate_data['Year'] < 2015]
len(climate_data)
# Out:
# 151245

# %%
climate_data['Year'].unique()
# Out:
# array([2014, 2009, 2008, 2005, 2010, 2007, 2011, 2013, 2006, 2012])

# %%
climate_data_max = climate_data[climate_data['Element'] == 'TMAX']
climate_data_min = climate_data[climate_data['Element'] == 'TMIN']
print(len(climate_data_max))
print(len(climate_data_min))
# Out:
# 76100
# 75145

# %%
climate_data_min['Year'].unique()
climate_data_max['Year'].unique()
# Out:
# array([2014, 2008, 2005, 2010, 2011, 2013, 2006, 2012, 2007, 2009])

# %%
min_records = pd.DataFrame(climate_data_min.groupby(['Date'], sort=True)['Data_Value'].min())
max_records = pd.DataFrame(climate_data_max.groupby(['Date'], sort=True)['Data_Value'].max())

# %%
plt.plot(min_records.index.tolist(), min_records.Data_Value.tolist())
plt.plot(max_records.index.tolist(), max_records.Data_Value.tolist())
ax = plt.gca()
plt.fill_between(max_records.index.tolist(), min_records.Data_Value.tolist(), max_records.Data_Value.tolist(), 
                 facecolor='grey', 
                 alpha=0.25)
record_high_10_year = climate_data_max['Data_Value'].max()
record_low_10_year = climate_data_min['Data_Value'].min()
scatter_data = climate_data_new[((climate_data_new['Data_Value'] < record_low_10_year) & (climate_data_new['Element'] == 'TMIN')) | ((climate_data_new['Data_Value'] > record_high_10_year) & (climate_data_new['Element'] == 'TMAX'))]
plt.scatter(scatter_data.Date.tolist(), scatter_data.Data_Value.tolist(), c='black', )
plt.ylabel('Temperature (tenths of degrees C)')
plt.xlabel('Date')
plt.legend(['Low Temperature', 'High Temperature',], loc=9, fontsize='xx-small')
plt.title('Low/High Temperature by Day')
# Out:
# <img src="data:image/png;base64,..." width="917">
